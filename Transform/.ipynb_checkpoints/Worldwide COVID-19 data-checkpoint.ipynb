# %%
#import dependencies
import os
import csv
import pandas as pd

# %%
# Path to collect data from the Resources folder

#1 - Worldwide COVID-19 Data

file_path = os.path.join('..', 'Resources', 'Ourworlddata_Covid_19_worldwide_data_set.csv')

# Import the Ourworlddata_Covid_19_worldwide_data_set.csv file as a DataFrame
covid_ww_df=pd.read_csv(file_path)

covid_ww_df.head(5)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
#Summary Statistics

covid_ww_df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.075600e+04   53469.000000        52669.000000  4.166700e+04
# mean   1.493619e+05    1761.487572         1732.743639  6.447778e+03
# std    1.499361e+06   16084.465899        15678.575064  5.229041e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.550000e+02       0.000000            0.714000  1.200000e+01
# 50%    1.884500e+03      13.000000           18.143000  7.800000e+01
# 75%    1.913900e+04     212.000000          220.857000  6.570000e+02
# max    4.709322e+07  547141.000000       492851.000000  1.207290e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  53469.000000         52669.000000             50483.000000
# mean      45.156184            45.137385              2759.791429
# std      374.862461           364.309001              5431.255524
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
# Finding how many unique locations are provided
covid_ww_df["location"].unique() #value_counts()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Bonaire Sint Eustatius and Saba',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt',
#        'Eritrea', 'Western Sahara', 'Spain', 'Estonia', 'Ethiopia',
# ...

# %%
#### new cases by location for each date (graph may provide insight)

# %%
##create a subset of the world wide data
columns = ["iso_code","continent","location",'stringency_index','population','population_density','median_age','gdp_per_capita','extreme_poverty','cardiovasc_death_rate','diabetes_prevalence','female_smokers','male_smokers','handwashing_facilities','hospital_beds_per_thousand','life_expectancy','human_development_index']

country_info_pd=covid_ww_df[columns]

country_info_pd.head()
# Out:
#   iso_code      continent location  gdp_per_capita  extreme_poverty  \
# 0      ABW  North America    Aruba       35973.781              NaN
# 1      ABW  North America    Aruba       35973.781              NaN
# 2      ABW  North America    Aruba       35973.781              NaN
# 3      ABW  North America    Aruba       35973.781              NaN
# 4      ABW  North America    Aruba       35973.781              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                    NaN                11.62             NaN           NaN
# 1                    NaN                11.62             NaN           NaN
# 2                    NaN                11.62             NaN           NaN
# 3                    NaN                11.62             NaN           NaN
# 4                    NaN                11.62             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# ...

# %%
country_grp= country_info_pd.groupby("location").mean()
country_grp
# Out:
#                 gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# location
# Afghanistan           1803.987              NaN                597.029
# Albania              11803.431              1.1                304.195
# Algeria              13913.839              0.5                278.364
# Andorra                    NaN              NaN                109.135
# Angola                5819.495              NaN                276.045
# ...                        ...              ...                    ...
# Western Sahara             NaN              NaN                    NaN
# World                15469.207             10.0                233.070
# Yemen                 1479.147             18.8                495.003
# Zambia                3689.251             57.5                234.499
# Zimbabwe              1899.775             21.4                307.846
#
#                 diabetes_prevalence  female_smokers  male_smokers  \
# location
# ...

# %%
### To Do: merge country_grp with the covid-metrics by date in columns or total cases etc?

# %%
#Group COVID Data by Country and Date

covid_grp_df= covid_ww_df.groupby(['location','date']).agg({"total_cases":'max',
                                                   "new_cases":'max',
                                                   #"new_cases_smoothed":'mean',
                                                   "total_deaths":'max',
                                                   "new_deaths": 'max',
                                                   "new_deaths_smoothed":'max',
                                                   "total_cases_per_million": 'max',
                                                   "new_cases_per_million": 'max',
                                                   "new_cases_smoothed_per_million": 'max',
                                                   "total_deaths_per_million": 'max',
                                                   "new_deaths_per_million": 'max',
                                                   "new_deaths_smoothed_per_million": 'max',
                                                   "icu_patients": 'max',
                                                   "icu_patients_per_million": 'max',
                                                   "weekly_icu_admissions": 'max',
                                                   "weekly_icu_admissions_per_million": 'max',
                                                   "weekly_hosp_admissions": 'max',
                                                   "weekly_hosp_admissions_per_million": 'max',
                                                   "total_tests": 'max',
                                                   "new_tests": 'max',
                                                   "total_tests_per_thousand": 'max',
                                                   "new_tests_per_thousand": 'max',
                                                   "new_tests_smoothed": 'max',
                                                   "new_tests_smoothed_per_thousand": 'max',
                                                   "tests_per_case": 'max',
                                                   "positive_rate": 'max',
                                                
                                                  })

covid_grp_df
# Out:
#                         total_cases  new_cases  total_deaths  new_deaths  \
# location    date
# Afghanistan 2019-12-31          NaN        0.0           NaN         0.0
#             2020-01-01          NaN        0.0           NaN         0.0
#             2020-01-02          NaN        0.0           NaN         0.0
#             2020-01-03          NaN        0.0           NaN         0.0
#             2020-01-04          NaN        0.0           NaN         0.0
# ...                             ...        ...           ...         ...
# Zimbabwe    2020-10-30       8349.0       29.0         242.0         0.0
#             2020-10-31       8362.0       13.0         242.0         0.0
#             2020-11-01       8362.0        0.0         242.0         0.0
#             2020-11-02       8374.0       12.0         243.0         1.0
#             2020-11-03       8389.0       15.0         245.0         2.0
#
#                         new_deaths_smoothed  total_cases_per_million  \
# ...

# %%
#Group COVID Data by Country only

covid_grp2_df= covid_ww_df.groupby(['location']).agg({"total_cases":'max',
                                                   "new_cases":'max',
                                                   #"new_cases_smoothed":'mean',
                                                   "total_deaths":'max',
                                                   "new_deaths": 'max',
                                                   "new_deaths_smoothed":'max',
                                                   "total_cases_per_million": 'max',
                                                   "new_cases_per_million": 'max',
                                                   "new_cases_smoothed_per_million": 'max',
                                                   "total_deaths_per_million": 'max',
                                                   "new_deaths_per_million": 'max',
                                                   "new_deaths_smoothed_per_million": 'max',
                                                   "icu_patients": 'max',
                                                   "icu_patients_per_million": 'max',
                                                   "weekly_icu_admissions": 'max',
                                                   "weekly_icu_admissions_per_million": 'max',
                                                   "weekly_hosp_admissions": 'max',
                                                   "weekly_hosp_admissions_per_million": 'max',
                                                   "total_tests": 'max',
                                                   "new_tests": 'max',
                                                   "total_tests_per_thousand": 'max',
                                                   "new_tests_per_thousand": 'max',
                                                   "new_tests_smoothed": 'max',
                                                   "new_tests_smoothed_per_thousand": 'max',
                                                   "tests_per_case": 'max',
                                                   "positive_rate": 'max',
                                                
                                                  })

covid_grp2_df
# Out:
#                 total_cases  new_cases  total_deaths  new_deaths  \
# location
# Afghanistan         41728.0     1063.0        1544.0        56.0
# Albania             21523.0      327.0         527.0         9.0
# Algeria             58574.0      675.0        1980.0        42.0
# Andorra              4888.0      299.0          75.0         6.0
# Angola              11035.0      355.0         286.0        13.0
# ...                     ...        ...           ...         ...
# Western Sahara        766.0      242.0           1.0         1.0
# World            47093222.0   547141.0     1207290.0     10491.0
# Yemen                2063.0      116.0         600.0        52.0
# Zambia              16543.0      527.0         349.0        40.0
# Zimbabwe             8389.0      490.0         245.0        18.0
#
#                 new_deaths_smoothed  total_cases_per_million  \
# location
# Afghanistan                  27.143                 1071.918
# ...
