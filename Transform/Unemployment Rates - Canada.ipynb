# %%
#import dependencies
import os
import csv
import pandas as pd

# %%
# Path to collect data from the Resources folder

#1 - Death Counts for Infections - Influenza, Pnuemonia, COVID-19

file_path = os.path.join('..', 'Resources', 'Unemployment_Rates_Canada_only.csv')

# Import the Unemployment_Rates_Canada_only.csv file as a DataFrame
unemployment_df=pd.read_csv(file_path)

unemployment_df.head(5)
# Out:
#    OBJECTID_1 postal           Name_EN                Nom_Fr  PRUID  \
# 0           1     MB          Manitoba              Manitoba     46
# 1           2     SK      Saskatchewan          Saskatchewan     47
# 2           3     AB           Alberta                           48
# 3           4     BC  British Columbia  Colombie-Britannique     59
# 4           5     NU           Nunavut               Nunavut     62
#
#            Province  PRUID_1  Jan20_15  Jan20_1524  Jan20_25  ...  Mar20_2554  \
# 0          Manitoba       46       5.1         9.2       4.3  ...         5.5
# 1      Saskatchewan       47       6.0        15.1       4.5  ...         6.1
# 2           Alberta       48       7.3        13.9       6.3  ...         7.2
# 3  British Columbia       59       4.5         8.6       3.8  ...         5.9
# 4           Nunavut       62       NaN         NaN       NaN  ...         NaN
#
#    Mar20_55  ObjectID  Apr20_15  Apr20_1524  Apr20_25  Apr20_2554  Apr20_55  \
# ...

# %%
########?????????data dictionary for column headings above
######??? shape_area, Shape_length

### no entries for Nunavut, Northwest Territories, Yukon
